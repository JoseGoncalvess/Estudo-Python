# %%
import pandas as pd
import xlrd

# %%
#leitura de  Dados CSV
df = pd.read_csv("https://pycourse.s3.amazonaws.com/temperature.csv")
df
# Out:
#          date  temperatura classification
# 0  2020-01-01         29.1         quente
# 1  2020-02-01         31.2   muito quente
# 2  2020-03-01         28.5         quente
# 3  2020-04-01         28.0         quente
# 4  2020-05-01         24.0    confortavel
# 5  2020-06-01         20.0           frio

# %%
# Plot de linahs
df.plot()
# Out:
# <Axes: >

# %%
#PLOT D ELINHAS : TAMNAHO
df.plot(figsize=(10,5))
# Out:
# <Axes: >

# %%
##PLOT D ELINHAS: GRID
df.plot(figsize=(10,5), grid=True)
# Out:
# <Axes: >

# %%
##PLOT D ELINHAS: style
df.plot(style="-o",  figsize=(10,5), grid=True)
# Out:
# <Axes: >

# %%
##PLOT D ELINHAS: style 2
df.plot(style="-",  figsize=(10,5), grid=True)
# Out:
# <Axes: >

# %%
##PLOT D ELINHAS: style 3
df.plot(style="-.",  figsize=(10,5), grid=True)
# Out:
# <Axes: >

# %%
##PLOT D ELINHAS: COLOR
df.plot(style="-o", linewidth=2.5,color="blue",  figsize=(10,5), grid=True)
# Out:
# <Axes: >

# %%
##PLOT D ELINHAS: COLOR
df.plot(style="-o", linewidth=2.5,color="green",  figsize=(10,5), grid=True)
# Out:
# <Axes: >

# %%
##PLOT D ELINHAS: COLOR HEXA DECIMAL 
df.plot(style="-o", linewidth=2.5,color="#f09b0a",  figsize=(10,5), grid=True)
# Out:
# <Axes: >

# %%
#PLOT DE BARRAS
df.plot(kind='bar', figsize=(10,5),rot=30)
# Out:
# <Axes: >

# %%
#PLOT DE BARRAS
df['classification'].value_counts().  plot(kind='bar', figsize=(10,5),rot=0)
# Out:
# <Axes: xlabel='classification'>

# %%
#pie plots
df['classification'].value_counts().plot.pie(autopct='%1.1f%%',shadow=False, figsize=(10,10));
